# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel('/kaggle/input/air-quality-chennai-jan-21-feb23/12.01.2021 to 01.02.2023 data.xlsx')
df.head()
# Out:
#    S. No.         From Date  PM2.5   PM10    NO    NO2    NOx   NH3   SO2  \
# 0       1  12-01-2021 00:00  24.21  46.97  2.81  15.62  10.59  6.67  5.67
# 1       2  13-01-2021 00:00  45.15  69.01  2.65  16.01  10.66  8.63  5.29
# 2       3  14-01-2021 00:00  32.03  49.90  1.92  13.24   8.60  8.43  4.25
# 3       4  15-01-2021 00:00  39.19  60.39  1.08  10.89   6.67  9.98  4.00
# 4       5  16-01-2021 00:00  29.91  56.37  1.78  15.73   9.79  9.59  4.56
#
#      CO  ...  Toluene      O     RH    WS      WD      SR      BP     AT  \
# 0  0.77  ...     0.86  25.59  83.42  2.22  116.29   15.29  756.08  27.45
# 1  0.70  ...     0.70  25.24  83.35  2.17  119.96   85.95  756.80  27.17
# 2  0.64  ...     0.66  25.30  86.94  1.79  123.29   49.22  756.46  26.35
# 3  0.62  ...     0.42  25.34  81.04  1.72  122.23  100.96  756.56  27.33
# 4  0.62  ...     1.16  26.66  74.68  1.75  145.91  116.95  755.91  27.47
#
#      RF  TOT-RF
# 0  0.00       0
# 1  0.00       0
# 2  0.15      14
# ...

# %%
df.shape
# Out:
# (751, 22)

# %%
df.isnull().sum()
# Out:
# S. No.       0
# From Date    0
# PM2.5        0
# PM10         0
# NO           0
# NO2          0
# NOx          0
# NH3          0
# SO2          0
# CO           0
# Ozone        0
# Benzene      0
# Toluene      0
# O            0
# RH           0
# WS           0
# WD           0
# SR           0
# BP           0
# AT           0
# RF           0
# TOT-RF       0
# dtype: int64

# %%
df.drop(columns=['S. No.','NO','Benzene','Toluene','O','RH','WS','WD','SR','BP','AT','RF','TOT-RF'],axis=1, inplace=True)
df.columns
# Out:
# Index(['From Date', 'PM2.5', 'PM10', 'NO2', 'NOx', 'NH3', 'SO2', 'CO',
#        'Ozone'],
#       dtype='object')

# %%
df.describe()
# Out:
#             PM2.5        PM10         NO2         NOx         NH3         SO2  \
# count  751.000000  751.000000  751.000000  751.000000  751.000000  751.000000
# mean    23.233675   47.712410   11.461238    7.905832    8.919947   10.465912
# std     17.601192   24.504446    7.422429    4.649319    2.794276    5.005179
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     11.725000   30.190000    7.320000    5.085000    7.240000    7.210000
# 50%     17.380000   43.920000   10.170000    7.270000    8.630000    9.790000
# 75%     29.660000   60.220000   14.475000    9.995000   10.010000   12.755000
# max    165.140000  178.680000   88.920000   61.060000   38.540000   42.160000
#
#                CO       Ozone
# count  751.000000  751.000000
# mean     0.547297   33.143063
# std      0.203424   13.473316
# min      0.000000    0.000000
# 25%      0.415000   23.630000
# 50%      0.540000   31.950000
# 75%      0.650000   40.280000
# ...

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90)
sns.barplot(x='From Date',y='PM2.5',data=df);
# sns.distplot(PM10,color="red", hist=False, rug=True, bins=100)

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90)
sns.barplot(x='From Date',y='PM10',data=df);

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90)
sns.barplot(x='From Date',y='SO2',data=df);

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90)
sns.barplot(x='From Date',y='NO2',data=df);

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90)
sns.barplot(x='From Date',y='NH3',data=df);

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90)
sns.barplot(x='From Date',y='CO',data=df);

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90)
sns.barplot(x='From Date',y='Ozone',data=df);

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90)
sns.barplot(x='From Date',y='NOx',data=df);

# %% [markdown]
# # ------------------------------------------------

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 751 entries, 0 to 750
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   From Date  751 non-null    object
#  1   PM2.5      751 non-null    float64
#  2   PM10       751 non-null    float64
#  3   NO2        751 non-null    float64
#  4   NOx        751 non-null    float64
#  5   NH3        751 non-null    float64
#  6   SO2        751 non-null    float64
#  7   CO         751 non-null    float64
#  8   Ozone      751 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 52.9+ KB

# %%
df.columns
# Out:
# Index(['From Date', 'PM2.5', 'PM10', 'NO2', 'NOx', 'NH3', 'SO2', 'CO',
#        'Ozone'],
#       dtype='object')

# %%
df.shape
# Out:
# (751, 9)

# %% [markdown]
# # Calculating Sub-Index

# %%
def get_PM25_subindex(x):
    if x <= 30:
        return x * 50 / 30
    elif x <= 60:
        return 50 + (x - 30) * 50 / 30
    elif x <= 90:
        return 100 + (x - 60) * 100 / 30
    elif x <= 120:
        return 200 + (x - 90) * 100 / 30
    elif x <= 250:
        return 300 + (x - 120) * 100 / 130
    elif x > 250:
        return 400 + (x - 250) * 100 / 130
    else:
        return 0

df["PM2.5_SubIndex"] = df["PM2.5"].apply(lambda x: get_PM25_subindex(x))

# %%
def get_PM10_subindex(x):
    if x <= 50:
        return x
    elif x <= 100:
        return x
    elif x <= 250:
        return 100 + (x - 100) * 100 / 150
    elif x <= 350:
        return 200 + (x - 250)
    elif x <= 430:
        return 300 + (x - 350) * 100 / 80
    elif x > 430:
        return 400 + (x - 430) * 100 / 80
    else:
        return 0

df["PM10_SubIndex"] = df["PM10"].apply(lambda x: get_PM10_subindex(x))

# %%
def get_SO2_subindex(x):
    if x <= 40:
        return x * 50 / 40
    elif x <= 80:
        return 50 + (x - 40) * 50 / 40
    elif x <= 380:
        return 100 + (x - 80) * 100 / 300
    elif x <= 800:
        return 200 + (x - 380) * 100 / 420
    elif x <= 1600:
        return 300 + (x - 800) * 100 / 800
    elif x > 1600:
        return 400 + (x - 1600) * 100 / 800
    else:
        return 0

df["SO2_SubIndex"] = df["SO2"].apply(lambda x: get_SO2_subindex(x))

# %%
def get_NOx_subindex(x):
    if x <= 40:
        return x * 50 / 40
    elif x <= 80:
        return 50 + (x - 40) * 50 / 40
    elif x <= 180:
        return 100 + (x - 80) * 100 / 100
    elif x <= 280:
        return 200 + (x - 180) * 100 / 100
    elif x <= 400:
        return 300 + (x - 280) * 100 / 120
    elif x > 400:
        return 400 + (x - 400) * 100 / 120
    else:
        return 0

df["NOx_SubIndex"] = df["NOx"].apply(lambda x: get_NOx_subindex(x))

# %%
def get_NH3_subindex(x):
    if x <= 200:
        return x * 50 / 200
    elif x <= 400:
        return 50 + (x - 200) * 50 / 200
    elif x <= 800:
        return 100 + (x - 400) * 100 / 400
    elif x <= 1200:
        return 200 + (x - 800) * 100 / 400
    elif x <= 1800:
        return 300 + (x - 1200) * 100 / 600
    elif x > 1800:
        return 400 + (x - 1800) * 100 / 600
    else:
        return 0

df["NH3_SubIndex"] = df["NH3"].apply(lambda x: get_NH3_subindex(x))

# %%
def get_CO_subindex(x):
    if x <= 1:
        return x * 50 / 1
    elif x <= 2:
        return 50 + (x - 1) * 50 / 1
    elif x <= 10:
        return 100 + (x - 2) * 100 / 8
    elif x <= 17:
        return 200 + (x - 10) * 100 / 7
    elif x <= 34:
        return 300 + (x - 17) * 100 / 17
    elif x > 34:
        return 400 + (x - 34) * 100 / 17
    else:
        return 0

df["CO_SubIndex"] = df["CO"].apply(lambda x: get_CO_subindex(x))

# %%
def get_NO2_subindex(x):
    if x <= 40:
        return x * 50 / 40
    elif x <= 80:
        return 50 + (x - 40) * 50 / 40
    elif x <= 380:
        return 100 + (x - 80) * 100 / 100
    elif x <= 800:
        return 200 + (x - 180) * 100 / 100
    elif x <= 1600:
        return 300 + (x - 280) * 100 / 120
    elif x > 1600:
        return 400 + (x - 400) * 100 / 120
    else:
        return 0

df["NO2_SubIndex"] = df["NO2"].apply(lambda x: get_NO2_subindex(x))

# %%
def get_O3_subindex(x):
    if x <= 50:
        return x * 50 / 50
    elif x <= 100:
        return 50 + (x - 50) * 50 / 50
    elif x <= 168:
        return 100 + (x - 100) * 100 / 68
    elif x <= 208:
        return 200 + (x - 168) * 100 / 40
    elif x <= 748:
        return 300 + (x - 208) * 100 / 539
    elif x > 748:
        return 400 + (x - 400) * 100 / 539
    else:
        return 0

df["O3_SubIndex"] = df["Ozone"].apply(lambda x: get_O3_subindex(x))

# %%
df.head()
# Out:
#           From Date  PM2.5   PM10    NO2    NOx   NH3   SO2    CO  Ozone  \
# 0  12-01-2021 00:00  24.21  46.97  15.62  10.59  6.67  5.67  0.77  35.52
# 1  13-01-2021 00:00  45.15  69.01  16.01  10.66  8.63  5.29  0.70  33.00
# 2  14-01-2021 00:00  32.03  49.90  13.24   8.60  8.43  4.25  0.64  28.69
# 3  15-01-2021 00:00  39.19  60.39  10.89   6.67  9.98  4.00  0.62  45.71
# 4  16-01-2021 00:00  29.91  56.37  15.73   9.79  9.59  4.56  0.62  43.76
#
#    PM2.5_SubIndex  PM10_SubIndex  SO2_SubIndex  NOx_SubIndex  NH3_SubIndex  \
# 0       40.350000          46.97        7.0875       13.2375        1.6675
# 1       75.250000          69.01        6.6125       13.3250        2.1575
# 2       53.383333          49.90        5.3125       10.7500        2.1075
# 3       65.316667          60.39        5.0000        8.3375        2.4950
# 4       49.850000          56.37        5.7000       12.2375        2.3975
#
#    CO_SubIndex  NO2_SubIndex  O3_SubIndex
# ...

# %% [markdown]
# # Calculating AQI

# %%
df["AQI_Value"] = round(df[["PM2.5_SubIndex", "PM10_SubIndex", "SO2_SubIndex", "NOx_SubIndex",
                                 "NH3_SubIndex", "CO_SubIndex", "O3_SubIndex"]].max(axis = 1))

# %%
def get_AQI_Range(x):
    if x <= 50:
        return "Good"
    elif x <= 100:
        return "Satisfactory"
    elif x <= 200:
        return "Moderate"
    elif x <= 300:
        return "Poor"
    elif x <= 400:
        return "Very Poor"
    elif x > 400:
        return "Severe"
    else:
        return np.NaN
df["AQI_Range"] = df["AQI_Value"].apply(lambda x: get_AQI_Range(x))

# %%
df.head()
# Out:
#           From Date  PM2.5   PM10    NO2    NOx   NH3   SO2    CO  Ozone  \
# 0  12-01-2021 00:00  24.21  46.97  15.62  10.59  6.67  5.67  0.77  35.52
# 1  13-01-2021 00:00  45.15  69.01  16.01  10.66  8.63  5.29  0.70  33.00
# 2  14-01-2021 00:00  32.03  49.90  13.24   8.60  8.43  4.25  0.64  28.69
# 3  15-01-2021 00:00  39.19  60.39  10.89   6.67  9.98  4.00  0.62  45.71
# 4  16-01-2021 00:00  29.91  56.37  15.73   9.79  9.59  4.56  0.62  43.76
#
#    PM2.5_SubIndex  PM10_SubIndex  SO2_SubIndex  NOx_SubIndex  NH3_SubIndex  \
# 0       40.350000          46.97        7.0875       13.2375        1.6675
# 1       75.250000          69.01        6.6125       13.3250        2.1575
# 2       53.383333          49.90        5.3125       10.7500        2.1075
# 3       65.316667          60.39        5.0000        8.3375        2.4950
# 4       49.850000          56.37        5.7000       12.2375        2.3975
#
#    CO_SubIndex  NO2_SubIndex  O3_SubIndex  AQI_Value     AQI_Range
# ...

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90)
sns.barplot(x='From Date',y='AQI_Value',data=df);

# %%
df['AQI_Range'].value_counts()
# Out:
# Good            441
# Satisfactory    277
# Moderate         27
# Poor              4
# Very Poor         2
# Name: AQI_Range, dtype: int64

# %% [markdown]
# # Train Test Split

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.metrics import r2_score

# %%
# X=df[['PM2.5_SubIndex','PM10_SubIndex','SO2_SubIndex','NOx_SubIndex','NH3_SubIndex','CO_SubIndex','NO2_SubIndex','O3_SubIndex']]
X=df[['PM2.5','PM10','NO2','NOx','NH3','SO2','CO','Ozone']]
Y=df['AQI_Value']

# %%
X.head()
# Out:
#    PM2.5   PM10    NO2    NOx   NH3   SO2    CO  Ozone
# 0  24.21  46.97  15.62  10.59  6.67  5.67  0.77  35.52
# 1  45.15  69.01  16.01  10.66  8.63  5.29  0.70  33.00
# 2  32.03  49.90  13.24   8.60  8.43  4.25  0.64  28.69
# 3  39.19  60.39  10.89   6.67  9.98  4.00  0.62  45.71
# 4  29.91  56.37  15.73   9.79  9.59  4.56  0.62  43.76

# %%
Y.head()
# Out:
# 0    47.0
# 1    75.0
# 2    53.0
# 3    65.0
# 4    56.0
# Name: AQI_Value, dtype: float64

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2, random_state=70)
print(X_train.shape,X_test.shape,Y_train.shape,Y_test.shape)
# Out:
# (600, 8) (151, 8) (600,) (151,)

# %%
sns.distplot(X_train,color="red", hist=False, rug=False, bins=100)
sns.distplot(X_test,color="yellow", hist=False, rug=False, bins=100)
plt.legend(labels=["X_train","X_test"])

# %% [markdown]
# # --------------------- Regression Models --------------------------

# %% [markdown]
# # 1) Linear Regression

# %%
LR=LinearRegression()
LR.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
train_pred_LR=LR.predict(X_train)
test_pred_LR=LR.predict(X_test)

# %%
RMSE_train=(np.sqrt(metrics.mean_squared_error(Y_train,train_pred_LR)))
RMSE_test=(np.sqrt(metrics.mean_squared_error(Y_test,test_pred_LR)))
print("RMSE TrainingData = ",str(RMSE_train))
print("RMSE TestData     = ",str(RMSE_test))
print('-'*50)
print('RSquared value on train: ',LR.score(X_train,Y_train))
print('RSquared value on test:  ',LR.score(X_test,Y_test))
# Out:
# RMSE TrainingData =  11.219824016665129
# RMSE TestData     =  7.899668462867737
# --------------------------------------------------
# RSquared value on train:  0.884891976284105
# RSquared value on test:   0.8208402124381673

# %%
plt.figure(figsize=(14,8))
ax=sns.distplot(Y_test, hist=False, color="r", label="Actual Value")
sns.distplot(test_pred_LR, hist=False, color="b", label="Predicted Values", ax=ax)

plt.title("Actual vs Predicted Values for AQI")
plt.legend()
plt.show()

# %% [markdown]
# # 2) Decision Tree Regression

# %%
DT=DecisionTreeRegressor()
DT.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
train_preds_DT=DT.predict(X_train)
test_preds_DT=DT.predict(X_test)

# %%
RMSE_train=(np.sqrt(metrics.mean_squared_error(Y_train,train_preds_DT)))
RMSE_test=(np.sqrt(metrics.mean_squared_error(Y_test,test_preds_DT)))
print("RMSE TrainingData = ",str(RMSE_train))
print("RMSE TestData     = ",str(RMSE_test))
print('-'*50)
print('RSquared value on train: ',DT.score(X_train,Y_train))
print('RSquared value on test:  ',DT.score(X_test,Y_test))
# Out:
# RMSE TrainingData =  0.0
# RMSE TestData     =  7.450943315540035
# --------------------------------------------------
# RSquared value on train:  1.0
# RSquared value on test:   0.8406157776948994

# %%
plt.figure(figsize=(14,8))
ax=sns.distplot(Y_test, hist=False, color="r", label="Actual Value")
sns.distplot(test_preds_DT, hist=False, color="b", label="Predicted Values", ax=ax)

plt.title("Actual vs Predicted Values for AQI")
plt.legend()
plt.show()

# %% [markdown]
# # 3) Random Forest Regression

# %%
RF=RandomForestRegressor().fit(X_train,Y_train)

# %%
train_preds_RF=RF.predict(X_train)
test_preds_RF=RF.predict(X_test)

# %%
RMSE_train=(np.sqrt(metrics.mean_squared_error(Y_train,train_preds_RF)))
RMSE_test=(np.sqrt(metrics.mean_squared_error(Y_test,test_preds_RF)))
print("RMSE TrainingData = ",str(RMSE_train))
print("RMSE TestData     = ",str(RMSE_test))
print('-'*50)
print('RSquared value on train: ',RF.score(X_train,Y_train))
print('RSquared value on test:  ',RF.score(X_test,Y_test))
# Out:
# RMSE TrainingData =  1.9164433203202225
# RMSE TestData     =  2.948024257001212
# --------------------------------------------------
# RSquared value on train:  0.9966416537832744
# RSquared value on test:   0.9750491747693472

# %%
plt.figure(figsize=(14,8))
ax=sns.distplot(Y_test, hist=False, color="r", label="Actual Value")
sns.distplot(test_preds_RF, hist=False, color="b", label="Predicted Values", ax=ax)

plt.title("Actual vs Predicted Values for AQI")
plt.legend()
plt.show()

# %% [markdown]
# # 4) XGBoost Regression

# %%
from xgboost import XGBRegressor
XGBR= XGBRegressor()
XGBR.fit(X_train, Y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
train_preds_XGBR=XGBR.predict(X_train)
test_preds_XGBR=XGBR.predict(X_test)

# %%
RMSE_train=(np.sqrt(metrics.mean_squared_error(Y_train,train_preds_XGBR)))
RMSE_test=(np.sqrt(metrics.mean_squared_error(Y_test,test_preds_XGBR)))
print("RMSE TrainingData = ",str(RMSE_train))
print("RMSE TestData     = ",str(RMSE_test))
print('-'*50)
print('RSquared value on train: ',XGBR.score(X_train,Y_train))
print('RSquared value on test:  ',XGBR.score(X_test,Y_test))
# Out:
# RMSE TrainingData =  0.04987423789499541
# RMSE TestData     =  2.175987894371442
# --------------------------------------------------
# RSquared value on train:  0.999997725499417
# RSquared value on test:   0.986406360176489

# %%
plt.figure(figsize=(14,8))
ax=sns.distplot(Y_test, hist=False, color="r", label="Actual Value")
sns.distplot(test_preds_XGBR, hist=False, color="b", label="Predicted Values", ax=ax)

plt.title("Actual vs Predicted Values for AQI")
plt.legend()
plt.show()

# %% [markdown]
# # CatBoost Regression

# %%
import catboost as ctb
CBR = ctb.CatBoostRegressor()
CBR.fit(X_train, Y_train)
# Out:
# Learning rate set to 0.037768
# 0:	learn: 32.2680039	total: 58.8ms	remaining: 58.7s
# 1:	learn: 31.4577490	total: 60.2ms	remaining: 30.1s
# 2:	learn: 30.7609408	total: 61.7ms	remaining: 20.5s
# 3:	learn: 29.9546411	total: 63.3ms	remaining: 15.8s
# 4:	learn: 29.2978332	total: 64.7ms	remaining: 12.9s
# 5:	learn: 28.6626098	total: 66.1ms	remaining: 10.9s
# 6:	learn: 28.0463472	total: 67.4ms	remaining: 9.56s
# 7:	learn: 27.4763206	total: 68.7ms	remaining: 8.52s
# 8:	learn: 26.8529775	total: 70ms	remaining: 7.71s
# 9:	learn: 26.3112933	total: 71.3ms	remaining: 7.06s
# 10:	learn: 25.7082618	total: 72.7ms	remaining: 6.54s
# 11:	learn: 25.1158119	total: 74.2ms	remaining: 6.11s
# 12:	learn: 24.5765947	total: 75.5ms	remaining: 5.73s
# 13:	learn: 24.0707924	total: 76.8ms	remaining: 5.41s
# 14:	learn: 23.5605823	total: 78.2ms	remaining: 5.13s
# 15:	learn: 23.1384667	total: 79.4ms	remaining: 4.88s
# 16:	learn: 22.6773885	total: 80.8ms	remaining: 4.67s
# ...

# %%
train_preds_CBR=CBR.predict(X_train)
test_preds_CBR=CBR.predict(X_test)

# %%
RMSE_train=(np.sqrt(metrics.mean_squared_error(Y_train,train_preds_CBR)))
RMSE_test=(np.sqrt(metrics.mean_squared_error(Y_test,test_preds_CBR)))
print("RMSE TrainingData = ",str(RMSE_train))
print("RMSE TestData     = ",str(RMSE_test))
print('-'*50)
print('RSquared value on train: ',CBR.score(X_train,Y_train))
print('RSquared value on test:  ',CBR.score(X_test,Y_test))
# Out:
# RMSE TrainingData =  0.46709426157774186
# RMSE TestData     =  2.6757168032082697
# --------------------------------------------------
# RSquared value on train:  0.9998005001510437
# RSquared value on test:   0.9794456806049452

# %%
plt.figure(figsize=(14,8))
ax=sns.distplot(Y_test, hist=False, color="r", label="Actual Value")
sns.distplot(test_preds_CBR, hist=False, color="b", label="Predicted Values", ax=ax)

plt.title("Actual vs Predicted Values for AQI")
plt.legend()
plt.show()

# %% [markdown]
# # Regression Comparison

# %%
data={
    '' : ['Linear Regression','Decision Tree','Random Forest','XGBoost','CatBoost'],
    'RMSE_test' : [(np.sqrt(metrics.mean_squared_error(Y_test,test_pred_LR))),(np.sqrt(metrics.mean_squared_error(Y_test,test_preds_DT))) ,(np.sqrt(metrics.mean_squared_error(Y_test,test_preds_RF))),(np.sqrt(metrics.mean_squared_error(Y_test,test_preds_XGBR))),(np.sqrt(metrics.mean_squared_error(Y_test,test_preds_CBR))) ],
    'RSquared value on test' : [LR.score(X_test,Y_test) ,DT.score(X_test,Y_test) ,RF.score(X_test,Y_test),XGBR.score(X_test,Y_test),CBR.score(X_test,Y_test) ],
}
data1=pd.DataFrame(data)
data1
# Out:
#                       RMSE_test  RSquared value on test
# 0  Linear Regression   7.899668                0.820840
# 1      Decision Tree   7.450943                0.840616
# 2      Random Forest   2.948024                0.975049
# 3            XGBoost   2.175988                0.986406
# 4           CatBoost   2.675717                0.979446

# %% [markdown]
# # -------------------------- Classification ----------------------------

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import confusion_matrix
import scikitplot as skplt

# %%
df.head()
# Out:
#           From Date  PM2.5   PM10    NO2    NOx   NH3   SO2    CO  Ozone  \
# 0  12-01-2021 00:00  24.21  46.97  15.62  10.59  6.67  5.67  0.77  35.52
# 1  13-01-2021 00:00  45.15  69.01  16.01  10.66  8.63  5.29  0.70  33.00
# 2  14-01-2021 00:00  32.03  49.90  13.24   8.60  8.43  4.25  0.64  28.69
# 3  15-01-2021 00:00  39.19  60.39  10.89   6.67  9.98  4.00  0.62  45.71
# 4  16-01-2021 00:00  29.91  56.37  15.73   9.79  9.59  4.56  0.62  43.76
#
#    PM2.5_SubIndex  PM10_SubIndex  SO2_SubIndex  NOx_SubIndex  NH3_SubIndex  \
# 0       40.350000          46.97        7.0875       13.2375        1.6675
# 1       75.250000          69.01        6.6125       13.3250        2.1575
# 2       53.383333          49.90        5.3125       10.7500        2.1075
# 3       65.316667          60.39        5.0000        8.3375        2.4950
# 4       49.850000          56.37        5.7000       12.2375        2.3975
#
#    CO_SubIndex  NO2_SubIndex  O3_SubIndex  AQI_Value     AQI_Range
# ...

# %%
X2=df[['PM2.5','PM10','NO2','NOx','NH3','SO2','CO','Ozone']]
Y2=df['AQI_Range']

# %%
X2.head()
# Out:
#    PM2.5   PM10    NO2    NOx   NH3   SO2    CO  Ozone
# 0  24.21  46.97  15.62  10.59  6.67  5.67  0.77  35.52
# 1  45.15  69.01  16.01  10.66  8.63  5.29  0.70  33.00
# 2  32.03  49.90  13.24   8.60  8.43  4.25  0.64  28.69
# 3  39.19  60.39  10.89   6.67  9.98  4.00  0.62  45.71
# 4  29.91  56.37  15.73   9.79  9.59  4.56  0.62  43.76

# %%
Y2.head()
# Out:
# 0            Good
# 1    Satisfactory
# 2    Satisfactory
# 3    Satisfactory
# 4    Satisfactory
# Name: AQI_Range, dtype: object

# %%
X_train2,X_test2,Y_train2,Y_test2 = train_test_split(X2,Y2, test_size=0.33, random_state=70)
print(X_train2.shape,X_test2.shape,Y_train2.shape,Y_test2.shape)
# Out:
# (503, 8) (248, 8) (503,) (248,)

# %% [markdown]
# # Logistic Regression

# %%
log_reg=LogisticRegression().fit(X_train2,Y_train2)
train_preds_LogR=log_reg.predict(X_train2)
test_preds_LogR=log_reg.predict(X_test2)

print("Model accuracy on train is: ",accuracy_score(Y_train2,train_preds_LogR))
print("Model accuracy on test is:  ",accuracy_score(Y_test2,test_preds_LogR))
print('-'*50)
print('KappaScore is: ',metrics.cohen_kappa_score(Y_test2,test_preds_LogR))
# Out:
# Model accuracy on train is:  0.8290258449304175
# Model accuracy on test is:   0.8306451612903226
# --------------------------------------------------
# KappaScore is:  0.6514989293361884

# %% [markdown]
# # Decision Tree Classifier

# %%
DTC= DecisionTreeClassifier().fit(X_train2,Y_train2)

train_preds_DTC=DTC.predict(X_train2)
test_preds_DTC=DTC.predict(X_test2)

print("Model accuracy on train is: ",accuracy_score(Y_train2,train_preds_DTC))
print("Model accuracy on test is:  ",accuracy_score(Y_test2,test_preds_DTC))
print('-'*50)
print('KappaScore is: ',metrics.cohen_kappa_score(Y_test2,test_preds_DTC))
# Out:
# Model accuracy on train is:  1.0
# Model accuracy on test is:   0.9959677419354839
# --------------------------------------------------
# KappaScore is:  0.9917937857781013

# %%
cm = confusion_matrix(Y_test2, test_preds_DTC)
print(cm)
# cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'],index=['Predict Positive:1', 'Predict Negative:0'])
# sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# [[153   0   0]
#  [  0   6   0]
#  [  0   1  88]]

# %% [markdown]
# # Random Forest Classifier

# %%
RFC=RandomForestClassifier().fit(X_train2,Y_train2)

train_preds_RFC=RFC.predict(X_train2)
test_preds_RFC=RFC.predict(X_test2)

print("Model accuracy on train is: ",accuracy_score(Y_train2,train_preds_RFC))
print("Model accuracy on test is:  ",accuracy_score(Y_test2,test_preds_RFC))
print('-'*50)
print('KappaScore is: ',metrics.cohen_kappa_score(Y_test2,test_preds_RFC))
# Out:
# Model accuracy on train is:  1.0
# Model accuracy on test is:   0.967741935483871
# --------------------------------------------------
# KappaScore is:  0.9335209757405174

# %% [markdown]
# # KNN

# %%
KNN=KNeighborsClassifier().fit(X_train2,Y_train2)
train_preds_KNN=KNN.predict(X_train2)
test_preds_KNN=KNN.predict(X_test2)

print("Model accuracy on train is: ",accuracy_score(Y_train2,train_preds_KNN))
print("Model accuracy on test is:  ",accuracy_score(Y_test2,test_preds_KNN))
print('-'*50)
print('KappaScore is: ',metrics.cohen_kappa_score(Y_test2,test_preds_KNN))
# Out:
# Model accuracy on train is:  0.9622266401590457
# Model accuracy on test is:   0.9395161290322581
# --------------------------------------------------
# KappaScore is:  0.8746250547672811

# %% [markdown]
# # CatBoost Classifier

# %%
CBC = ctb.CatBoostClassifier()
CBC.fit(X_train2,Y_train2)
# Out:
# Learning rate set to 0.076402
# 0:	learn: 1.4593967	total: 11.7ms	remaining: 11.7s
# 1:	learn: 1.2957868	total: 16.5ms	remaining: 8.24s
# 2:	learn: 1.1639789	total: 21.7ms	remaining: 7.22s
# 3:	learn: 1.0698628	total: 26.6ms	remaining: 6.63s
# 4:	learn: 0.9779375	total: 31.7ms	remaining: 6.3s
# 5:	learn: 0.9011790	total: 38.7ms	remaining: 6.41s
# 6:	learn: 0.8314695	total: 44.3ms	remaining: 6.29s
# 7:	learn: 0.7696886	total: 49.1ms	remaining: 6.09s
# 8:	learn: 0.7166271	total: 54.2ms	remaining: 5.96s
# 9:	learn: 0.6717971	total: 61.4ms	remaining: 6.08s
# 10:	learn: 0.6249240	total: 66.6ms	remaining: 5.99s
# 11:	learn: 0.5949842	total: 71.7ms	remaining: 5.9s
# 12:	learn: 0.5603941	total: 76.2ms	remaining: 5.78s
# 13:	learn: 0.5302798	total: 80.9ms	remaining: 5.7s
# 14:	learn: 0.4982511	total: 85.8ms	remaining: 5.63s
# 15:	learn: 0.4714809	total: 90.5ms	remaining: 5.57s
# 16:	learn: 0.4444290	total: 96.1ms	remaining: 5.55s
# 17:	learn: 0.4209368	total: 101ms	remaining: 5.51s
# ...

# %%
train_preds_CBC=CBC.predict(X_train2)
test_preds_CBC=CBC.predict(X_test2)
print("Model accuracy on train is: ",accuracy_score(Y_train2,train_preds_CBC))
print("Model accuracy on test is:  ",accuracy_score(Y_test2,test_preds_CBC))
print('-'*50)
print('KappaScore is: ',metrics.cohen_kappa_score(Y_test2,test_preds_CBC))
# Out:
# Model accuracy on train is:  1.0
# Model accuracy on test is:   0.9717741935483871
# --------------------------------------------------
# KappaScore is:  0.9423121656199116

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
GNB = GaussianNB()
GNB.fit(X_train2, Y_train2)
# Out:
# GaussianNB()

# %%
train_preds_GNB=GNB.predict(X_train2)
test_preds_GNB=GNB.predict(X_test2)
print("Model accuracy on train is: ",accuracy_score(Y_train2,train_preds_GNB))
print("Model accuracy on test is:  ",accuracy_score(Y_test2,test_preds_GNB))
print('-'*50)
print('KappaScore is: ',metrics.cohen_kappa_score(Y_test2,test_preds_GNB))
# Out:
# Model accuracy on train is:  0.882703777335984
# Model accuracy on test is:   0.8870967741935484
# --------------------------------------------------
# KappaScore is:  0.7667685486850502

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
GBC=GradientBoostingClassifier(n_estimators=500,learning_rate=0.05,random_state=100,max_features=5 )
GBC.fit(X_train2,Y_train2)
# Out:
# GradientBoostingClassifier(learning_rate=0.05, max_features=5, n_estimators=500,
#                            random_state=100)

# %%
train_preds_GBC=GBC.predict(X_train2)
test_preds_GBC=GBC.predict(X_test2)
print("Model accuracy on train is: ",accuracy_score(Y_train2,train_preds_GBC))
print("Model accuracy on test is:  ",accuracy_score(Y_test2,test_preds_GBC))
print('-'*50)
print('KappaScore is: ',metrics.cohen_kappa_score(Y_test2,test_preds_GBC))
# Out:
# Model accuracy on train is:  1.0
# Model accuracy on test is:   0.9758064516129032
# --------------------------------------------------
# KappaScore is:  0.9502357780676232

# %% [markdown]
# # Classification Comparison

# %%
data={
    '' : ['Logistic Regression','Decision Tree','Random Forest','KNN','CatBoost','Naive Bayes','Gradient Boosting'],
    'Model Accuracy (Test)' : [accuracy_score(Y_test2,test_preds_LogR),accuracy_score(Y_test2,test_preds_DTC),accuracy_score(Y_test2,test_preds_RFC),accuracy_score(Y_test2,test_preds_KNN),accuracy_score(Y_test2,test_preds_CBC),accuracy_score(Y_test2,test_preds_GNB),accuracy_score(Y_test2,test_preds_GBC) ],
    'Kappa Score' : [metrics.cohen_kappa_score(Y_test2,test_preds_LogR),metrics.cohen_kappa_score(Y_test2,test_preds_DTC),metrics.cohen_kappa_score(Y_test2,test_preds_RFC),metrics.cohen_kappa_score(Y_test2,test_preds_KNN),metrics.cohen_kappa_score(Y_test2,test_preds_CBC),metrics.cohen_kappa_score(Y_test2,test_preds_GNB),metrics.cohen_kappa_score(Y_test2,test_preds_CBC) ],
}
data1=pd.DataFrame(data)
data1
# Out:
#                         Model Accuracy (Test)  Kappa Score
# 0  Logistic Regression               0.830645     0.651499
# 1        Decision Tree               0.995968     0.991794
# 2        Random Forest               0.967742     0.933521
# 3                  KNN               0.939516     0.874625
# 4             CatBoost               0.971774     0.942312
# 5          Naive Bayes               0.887097     0.766769
# 6    Gradient Boosting               0.975806     0.942312

# %% [markdown]
# # ------------------------------ Overall Comparision -----------------------------------

# %%
data={
    'Classification' : ['Logistic Regression','Decision Tree','Random Forest','KNN','CatBoost','Naive Bayes','Gradient Boosting'],
    'Model Accuracy (Test)' : [accuracy_score(Y_test2,test_preds_LogR),accuracy_score(Y_test2,test_preds_DTC),accuracy_score(Y_test2,test_preds_RFC),accuracy_score(Y_test2,test_preds_KNN),accuracy_score(Y_test2,test_preds_CBC),accuracy_score(Y_test2,test_preds_GNB),accuracy_score(Y_test2,test_preds_GBC) ],
    'Kappa Score' : [metrics.cohen_kappa_score(Y_test2,test_preds_LogR),metrics.cohen_kappa_score(Y_test2,test_preds_DTC),metrics.cohen_kappa_score(Y_test2,test_preds_RFC),metrics.cohen_kappa_score(Y_test2,test_preds_KNN),metrics.cohen_kappa_score(Y_test2,test_preds_CBC),metrics.cohen_kappa_score(Y_test2,test_preds_GNB),metrics.cohen_kappa_score(Y_test2,test_preds_CBC) ],
    '' : ['|','|','|','|','|','|','|'],
    'Regression': ['Linear Regression','Decision Tree','Random Forest','XGBoost','CatBoost','-','-'],
    'RMSE_test' : [(np.sqrt(metrics.mean_squared_error(Y_test,test_pred_LR))),(np.sqrt(metrics.mean_squared_error(Y_test,test_preds_DT))) ,(np.sqrt(metrics.mean_squared_error(Y_test,test_preds_RF))),(np.sqrt(metrics.mean_squared_error(Y_test,test_preds_XGBR))),(np.sqrt(metrics.mean_squared_error(Y_test,test_preds_CBR))),'-','-' ],
    'RSquared value on test' : [LR.score(X_test,Y_test) ,DT.score(X_test,Y_test) ,RF.score(X_test,Y_test),XGBR.score(X_test,Y_test),CBR.score(X_test,Y_test),'-','-' ],
}
data1=pd.DataFrame(data)
data1
# Out:
#         Classification  Model Accuracy (Test)  Kappa Score     \
# 0  Logistic Regression               0.830645     0.651499  |
# 1        Decision Tree               0.995968     0.991794  |
# 2        Random Forest               0.967742     0.933521  |
# 3                  KNN               0.939516     0.874625  |
# 4             CatBoost               0.971774     0.942312  |
# 5          Naive Bayes               0.887097     0.766769  |
# 6    Gradient Boosting               0.975806     0.942312  |
#
#           Regression RMSE_test RSquared value on test
# 0  Linear Regression  7.899668                0.82084
# 1      Decision Tree  7.450943               0.840616
# 2      Random Forest  2.948024               0.975049
# 3            XGBoost  2.175988               0.986406
# 4           CatBoost  2.675717               0.979446
# 5                  -         -                      -
# 6                  -         -                      -

# %% [markdown]
# #
